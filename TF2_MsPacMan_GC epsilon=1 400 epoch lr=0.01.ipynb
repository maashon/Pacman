# %% [markdown]
# # Building an Agent to Play Miss PacMan games using Deep Q Network, in Tensorflow 2.0.
#
# ### A Colaboratory notebook for GradientCrescent, by Adrian Yijie Xu.
#
# ### If you enjoyed this notebook, please consider leaving a star on the GradientCrescent Github (https://github.com/EXJUSTICE/GradientCrescent), and visting the publication for more articles on applied and theoretical aspects of AI (https://medium.com/gradientcrescent).

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ## Training
#
# First we import all the necessary libraries </font>

# %%
import numpy as np
import gym
import tensorflow as tf
from tensorflow.contrib.layers import flatten, conv2d, fully_connected
from collections import deque, Counter
import random
from datetime import datetime

# %%
print(tf.__version__)
# Out:
# 1.15.2

# %% [markdown]
# Now we define a preprocessing function for our input game screens. We crop the image size convert the image into greyscale 1D tensor

# %%
color = np.array([210, 164, 74]).mean()


#prepro (210, 160, 3) uint8 frame into 7040 (88x80) 1D float vector 

def preprocess_observation(obs):

    # Crop and resize the image
    img = obs[1:176:2, ::2]

    # Convert the image to greyscale
    img = img.mean(axis=2)

    # Improve image contrast
    img[img==color] = 0

    # Next we normalize the image from -1 to +1
    img = (img - 128) / 128 - 1

    return img.reshape(88,80,1)

# %% [markdown]
# Let us initialize our gym environment, and take a look at some observations. Let's also inspect the size and type of action space in this game.

# %%
env = gym.make("MsPacman-v0")
n_outputs = env.action_space.n
print(n_outputs)
print(env.env.get_action_meanings())

observation = env.reset()

import tensorflow as tf
import matplotlib.pyplot as plt


for i in range(22):
  
  if i > 20:
    plt.imshow(observation)
    plt.show()

  observation, _, _, _ = env.step(1)
# Out:
# 9
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']

# %%
#Take a look at the preprocessed inputs in greyscale
#Let's compare the original and preprocessed tensors.

obs_preprocessed = preprocess_observation(observation).reshape(88,80)
plt.imshow(obs_preprocessed)
plt.show()
print(observation.shape)
print(obs_preprocessed.shape)
# Out:
# (210, 160, 3)
# (88, 80)

# %% [markdown]
# Okay, Now we define a function called q_network for building our Deep Q network.  <br>
# We build Q network with three convolutional layers with same padding followed by a flattening, and a fully connected layer.

# %%
tf.compat.v1.reset_default_graph()
#Reset is technically not necessary if variables done  in TF2
#https://github.com/ageron/tf2_course/issues/8

def q_network(X, name_scope):
    
    # Initialize layers
    initializer = tf.compat.v1.keras.initializers.VarianceScaling(scale=2.0)

    with tf.compat.v1.variable_scope(name_scope) as scope: 


        # initialize the convolutional layers
        layer_1 = conv2d(X, num_outputs=32, kernel_size=(8,8), stride=4, padding='SAME', weights_initializer=initializer) 
        tf.compat.v1.summary.histogram('layer_1',layer_1)
        
        layer_2 = conv2d(layer_1, num_outputs=64, kernel_size=(4,4), stride=2, padding='SAME', weights_initializer=initializer)
        tf.compat.v1.summary.histogram('layer_2',layer_2)
        
        layer_3 = conv2d(layer_2, num_outputs=64, kernel_size=(3,3), stride=1, padding='SAME', weights_initializer=initializer)
        tf.compat.v1.summary.histogram('layer_3',layer_3)
        
        # Flatten the result of layer_3 before feeding to the fully connected layer
        flat = flatten(layer_3)
        # Insert fully connected layer
        fc = fully_connected(flat, num_outputs=128, weights_initializer=initializer)
        tf.compat.v1.summary.histogram('fc',fc)
        #Add final output layer
        output = fully_connected(fc, num_outputs=n_outputs, activation_fn=None, weights_initializer=initializer)
        tf.compat.v1.summary.histogram('output',output)
        

        # Vars will store the parameters of the network such as weights
        vars = {v.name[len(scope.name):]: v for v in tf.compat.v1.get_collection(key=tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=scope.name)} 
        #Return both variables and outputs together
        return vars, output

# %% [markdown]
# Next we define a function called epsilon_greedy for performing epsilon greedy policy.
#
# In epsilon greedy policy we either select the best action with probability [1 - epsilon] or a random action with
# probability [epsilon].
#
#
# We use decaying epsilon greedy policy where value of epsilon will be decaying over time as we don't want to explore
# forever. So over time our policy will be exploiting only good actions.

# %%
epsilon = 1
eps_min = 0.05
eps_max = 1.0
eps_decay_steps = 500000

#
def epsilon_greedy(action, step):
    p = np.random.random(1).squeeze() #1D entries returned using squeeze
    epsilon = max(eps_min, eps_max - (eps_max-eps_min) * step/eps_decay_steps) #Decaying policy with more steps
    if np.random.rand() < epsilon:
        return np.random.randint(n_outputs)
    else:
        return action

# %% [markdown]
# Now, we initialize our  buffer of length 20000 which holds the gameplay information in SARSA.
#
# We store all the agent's experience i.e (state, action, rewards) in the experience replay buffer
# and  we sample from this minibatch of experience for generating the y-values for the update function, and hence train the network.

# %%
buffer_len = 20000
#Buffer is made from a deque - double ended queue
exp_buffer = deque(maxlen=buffer_len)

# %% [markdown]
# Next, we define a function called sample_memories for sampling experiences from the memory according to batches. Batch size is the number of experience sampled
# from the memory.

# %%
def sample_memories(batch_size):
    perm_batch = np.random.permutation(len(exp_buffer))[:batch_size]
    mem = np.array(exp_buffer)[perm_batch]
    return mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]

# %% [markdown]
# Now we define our network hyperparameters,

# %%
num_episodes = 400
batch_size = 48
input_shape = (None, 88, 80, 1)
#Recall shape is img.reshape(88,80,1)
learning_rate = 0.01
X_shape = (None, 88, 80, 1)
discount_factor = 0.97

global_step = 0
copy_steps = 100
steps_train = 4
start_steps = 2000

# %%
logdir = 'logs'
tf.compat.v1.reset_default_graph()

# Now we define the placeholder for our input i.e game state
X = tf.compat.v1.placeholder(tf.float32, shape=X_shape)

# we define a boolean called in_training_model to toggle the training
in_training_mode = tf.compat.v1.placeholder(tf.bool)

# %% [markdown]
#  Now let us build our primary and target Q network We have two networks to allow for training and data generation to occur concurrently.
#  Note that the network returns the weights, as well as network outputs.

# %%
# we build our Q network, which takes the input X and generates Q values for all the actions in the state
mainQ, mainQ_outputs = q_network(X, 'mainQ')

# similarly we build our target Q network
targetQ, targetQ_outputs = q_network(X, 'targetQ')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.

# %%
# define the placeholder for our action values

X_action = tf.compat.v1.placeholder(tf.int32, shape=(None,))
Q_action = tf.reduce_sum(input_tensor=targetQ_outputs * tf.one_hot(X_action, n_outputs), axis=-1, keepdims=True)

# %% [markdown]
# Copy the primary Q network parameters to the target  Q network

# %%
copy_op = [tf.compat.v1.assign(main_name, targetQ[var_name]) for var_name, main_name in mainQ.items()]
copy_target_to_main = tf.group(*copy_op)

# %% [markdown]
# Compute and optimize loss using gradient descent optimizer

# %%
# define a placeholder for our output i.e action
y = tf.compat.v1.placeholder(tf.float32, shape=(None,1))

# now we calculate the loss which is the difference between actual value and predicted value
loss = tf.reduce_mean(input_tensor=tf.square(y - Q_action))

# we use adam optimizer for minimizing the loss
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

init = tf.compat.v1.global_variables_initializer()

loss_summary = tf.compat.v1.summary.scalar('LOSS', loss)
merge_summary = tf.compat.v1.summary.merge_all()
file_writer = tf.compat.v1.summary.FileWriter(logdir, tf.compat.v1.get_default_graph())

# %% [markdown]
#  Now we start the tensorflow session and run the model,
#
# 1. First, we preprocess and feed the game screen (state s) to our DQN, which will
# return the Q values of all possible actions in the state.
# 2. Now we select an action using the epsilon-greedy policy: with the probability
# epsilon, we select a random action a and with probability 1-epsilon, we select an
# action that has a maximum Q value, such as .
# 3. After selecting the action a, we perform this action in a state s and move to a new
# state s' and receive a reward. The next state, s', is the preprocessed image of the
# next game screen.
# 4. We store this transition in our replay buffer as <s,a,r,s'>.
# 5. Next, we sample some random batches of transitions from the replay buffer and
# calculate the loss.
#
# 6. We know that the loss is defined as the squared
# difference between target Q and predicted Q.
#
# 7. We perform gradient descent with respect to our actual network parameters in
# order to minimize this loss.
#
# 8. Copy weights of training network to actual network
# 9. Repeat for M steps
#
# Epochs here exist because we are suplying data in batches.

# %%
with tf.compat.v1.Session() as sess:
    init.run()
    
    # for each episode
    history = []
    for i in range(num_episodes):
        done = False
        obs = env.reset()
        epoch = 0
        episodic_reward = 0
        actions_counter = Counter() 
        episodic_loss = []

        # while the state is not the terminal state
        while not done:

           #env.render()
        
            # get the preprocessed game screen
            obs = preprocess_observation(obs)

            # feed the game screen and get the Q values for each action,  FEED THE NETWORK BY CALLING THE OUTPUT LAYER
            
            actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})

            # get the action
            action = np.argmax(actions, axis=-1)
            actions_counter[str(action)] += 1 

            # select the action using epsilon greedy policy
            action = epsilon_greedy(action, global_step)
            
            # now perform the action and move to the next state, next_obs, receive reward
            next_obs, reward, done, _ = env.step(action)

            # Store this transistion as an experience in the replay buffer! Quite important
            exp_buffer.append([obs, action, preprocess_observation(next_obs), reward, done])
            
            # After certain steps, we train our Q network with samples from the experience replay buffer
            if global_step % steps_train == 0 and global_step > start_steps:
                
                # sample experience, mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]
                o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)

                # states
                o_obs = [x for x in o_obs]

                # next states
                o_next_obs = [x for x in o_next_obs]

                # next actions
                next_act = mainQ_outputs.eval(feed_dict={X:o_next_obs, in_training_mode:False})


                # discounted reward: these are our Y-values
                y_batch = o_rew + discount_factor * np.max(next_act, axis=-1) * (1-o_done) 

                # merge all summaries and write to the file
                mrg_summary = merge_summary.eval(feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:False})
                file_writer.add_summary(mrg_summary, global_step)

                # To calculate the loss, we run the previously defined functions mentioned while feeding inputs
                train_loss, _ = sess.run([loss, training_op], feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:True})
                episodic_loss.append(train_loss)
            
            # after some interval we copy our main Q network weights to target Q network
            if (global_step+1) % copy_steps == 0 and global_step > start_steps:
                copy_target_to_main.run()
                
            obs = next_obs
            epoch += 1
            global_step += 1
            episodic_reward += reward
        
        history.append(episodic_reward)
        print('Epochs per episode:', epoch, 'Episode Reward:', episodic_reward,"Episode number:", len(history))
# Out:
# Epochs per episode: 709 Episode Reward: 190.0 Episode number: 1
# Epochs per episode: 538 Episode Reward: 160.0 Episode number: 2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epochs per episode: 950 Episode Reward: 330.0 Episode number: 3
# Epochs per episode: 748 Episode Reward: 290.0 Episode number: 4
# Epochs per episode: 637 Episode Reward: 150.0 Episode number: 5
# Epochs per episode: 607 Episode Reward: 110.0 Episode number: 6
# Epochs per episode: 623 Episode Reward: 310.0 Episode number: 7
# Epochs per episode: 678 Episode Reward: 180.0 Episode number: 8
# Epochs per episode: 561 Episode Reward: 190.0 Episode number: 9
# Epochs per episode: 676 Episode Reward: 190.0 Episode number: 10
# Epochs per episode: 549 Episode Reward: 150.0 Episode number: 11
# Epochs per episode: 608 Episode Reward: 200.0 Episode number: 12
# Epochs per episode: 717 Episode Reward: 240.0 Episode number: 13
# Epochs per episode: 585 Episode Reward: 130.0 Episode number: 14
# Epochs per episode: 597 Episode Reward: 150.0 Episode number: 15
# Epochs per episode: 725 Episode Reward: 230.0 Episode number: 16
# Epochs per episode: 660 Episode Reward: 240.0 Episode number: 17
# Epochs per episode: 545 Episode Reward: 180.0 Episode number: 18
# Epochs per episode: 626 Episode Reward: 200.0 Episode number: 19
# Epochs per episode: 492 Episode Reward: 170.0 Episode number: 20
# Epochs per episode: 622 Episode Reward: 220.0 Episode number: 21
# Epochs per episode: 464 Episode Reward: 190.0 Episode number: 22
# Epochs per episode: 673 Episode Reward: 260.0 Episode number: 23
# Epochs per episode: 767 Episode Reward: 210.0 Episode number: 24
# Epochs per episode: 881 Episode Reward: 340.0 Episode number: 25
# Epochs per episode: 729 Episode Reward: 220.0 Episode number: 26
# Epochs per episode: 670 Episode Reward: 220.0 Episode number: 27
# Epochs per episode: 656 Episode Reward: 280.0 Episode number: 28
# Epochs per episode: 598 Episode Reward: 210.0 Episode number: 29
# Epochs per episode: 402 Episode Reward: 170.0 Episode number: 30
# Epochs per episode: 702 Episode Reward: 260.0 Episode number: 31
# Epochs per episode: 646 Episode Reward: 100.0 Episode number: 32
# Epochs per episode: 695 Episode Reward: 170.0 Episode number: 33
# Epochs per episode: 534 Episode Reward: 160.0 Episode number: 34
# Epochs per episode: 915 Episode Reward: 960.0 Episode number: 35
# Epochs per episode: 603 Episode Reward: 220.0 Episode number: 36
# Epochs per episode: 777 Episode Reward: 270.0 Episode number: 37
# Epochs per episode: 623 Episode Reward: 200.0 Episode number: 38
# Epochs per episode: 531 Episode Reward: 120.0 Episode number: 39
# Epochs per episode: 506 Episode Reward: 160.0 Episode number: 40
# Epochs per episode: 601 Episode Reward: 190.0 Episode number: 41
# Epochs per episode: 619 Episode Reward: 200.0 Episode number: 42
# Epochs per episode: 550 Episode Reward: 250.0 Episode number: 186
# Epochs per episode: 473 Episode Reward: 200.0 Episode number: 187
# Epochs per episode: 614 Episode Reward: 180.0 Episode number: 188
# Epochs per episode: 1728 Episode Reward: 730.0 Episode number: 189
# Epochs per episode: 489 Episode Reward: 250.0 Episode number: 190
# Epochs per episode: 651 Episode Reward: 290.0 Episode number: 191
# Epochs per episode: 542 Episode Reward: 130.0 Episode number: 192
# Epochs per episode: 703 Episode Reward: 150.0 Episode number: 193
# Epochs per episode: 573 Episode Reward: 300.0 Episode number: 194
# Epochs per episode: 666 Episode Reward: 230.0 Episode number: 195
# Epochs per episode: 466 Episode Reward: 200.0 Episode number: 196
# Epochs per episode: 576 Episode Reward: 210.0 Episode number: 197
# Epochs per episode: 677 Episode Reward: 310.0 Episode number: 198
# Epochs per episode: 722 Episode Reward: 310.0 Episode number: 199
# Epochs per episode: 610 Episode Reward: 180.0 Episode number: 200
# Epochs per episode: 630 Episode Reward: 240.0 Episode number: 201
# Epochs per episode: 545 Episode Reward: 230.0 Episode number: 202
# Epochs per episode: 787 Episode Reward: 300.0 Episode number: 203
# Epochs per episode: 589 Episode Reward: 270.0 Episode number: 204
# Epochs per episode: 379 Episode Reward: 180.0 Episode number: 205
# Epochs per episode: 697 Episode Reward: 260.0 Episode number: 206
# Epochs per episode: 516 Episode Reward: 180.0 Episode number: 207
# Epochs per episode: 622 Episode Reward: 240.0 Episode number: 208
# Epochs per episode: 867 Episode Reward: 330.0 Episode number: 209
# Epochs per episode: 556 Episode Reward: 280.0 Episode number: 210
# Epochs per episode: 656 Episode Reward: 210.0 Episode number: 211
# Epochs per episode: 657 Episode Reward: 250.0 Episode number: 212
# Epochs per episode: 843 Episode Reward: 660.0 Episode number: 213
# Epochs per episode: 815 Episode Reward: 270.0 Episode number: 214
# Epochs per episode: 597 Episode Reward: 260.0 Episode number: 215
# Epochs per episode: 612 Episode Reward: 180.0 Episode number: 216
# Epochs per episode: 620 Episode Reward: 250.0 Episode number: 217
# Epochs per episode: 781 Episode Reward: 350.0 Episode number: 218
# Epochs per episode: 645 Episode Reward: 310.0 Episode number: 219
# Epochs per episode: 1101 Episode Reward: 820.0 Episode number: 220
# Epochs per episode: 805 Episode Reward: 400.0 Episode number: 221
# Epochs per episode: 688 Episode Reward: 310.0 Episode number: 222
# Epochs per episode: 643 Episode Reward: 350.0 Episode number: 223
# Epochs per episode: 692 Episode Reward: 320.0 Episode number: 224
# Epochs per episode: 488 Episode Reward: 310.0 Episode number: 225
# Epochs per episode: 667 Episode Reward: 240.0 Episode number: 226
# Epochs per episode: 587 Episode Reward: 280.0 Episode number: 227
# Epochs per episode: 624 Episode Reward: 170.0 Episode number: 228
# Epochs per episode: 495 Episode Reward: 230.0 Episode number: 229
# Epochs per episode: 680 Episode Reward: 280.0 Episode number: 230
# Epochs per episode: 514 Episode Reward: 170.0 Episode number: 231
# Epochs per episode: 898 Episode Reward: 560.0 Episode number: 232
# Epochs per episode: 429 Episode Reward: 140.0 Episode number: 233
# Epochs per episode: 746 Episode Reward: 400.0 Episode number: 234
# Epochs per episode: 639 Episode Reward: 430.0 Episode number: 235
# Epochs per episode: 960 Episode Reward: 470.0 Episode number: 236
# Epochs per episode: 583 Episode Reward: 370.0 Episode number: 237
# Epochs per episode: 655 Episode Reward: 270.0 Episode number: 238
# Epochs per episode: 479 Episode Reward: 190.0 Episode number: 239
# Epochs per episode: 988 Episode Reward: 680.0 Episode number: 240
# Epochs per episode: 606 Episode Reward: 280.0 Episode number: 241
# Epochs per episode: 458 Episode Reward: 90.0 Episode number: 242
# Epochs per episode: 676 Episode Reward: 280.0 Episode number: 243
# Epochs per episode: 681 Episode Reward: 330.0 Episode number: 244
# Epochs per episode: 780 Episode Reward: 550.0 Episode number: 245
# Epochs per episode: 778 Episode Reward: 640.0 Episode number: 246
# Epochs per episode: 692 Episode Reward: 270.0 Episode number: 247
# Epochs per episode: 687 Episode Reward: 330.0 Episode number: 248
# Epochs per episode: 1071 Episode Reward: 500.0 Episode number: 249
# Epochs per episode: 982 Episode Reward: 990.0 Episode number: 250
# Epochs per episode: 1009 Episode Reward: 870.0 Episode number: 251
# Epochs per episode: 1387 Episode Reward: 830.0 Episode number: 252
# Epochs per episode: 802 Episode Reward: 490.0 Episode number: 253
# Epochs per episode: 676 Episode Reward: 270.0 Episode number: 254
# Epochs per episode: 688 Episode Reward: 330.0 Episode number: 255
# Epochs per episode: 720 Episode Reward: 410.0 Episode number: 256
# Epochs per episode: 594 Episode Reward: 140.0 Episode number: 257
# Epochs per episode: 752 Episode Reward: 990.0 Episode number: 258
# Epochs per episode: 718 Episode Reward: 270.0 Episode number: 259
# Epochs per episode: 1045 Episode Reward: 600.0 Episode number: 260
# Epochs per episode: 704 Episode Reward: 240.0 Episode number: 261
# Epochs per episode: 563 Episode Reward: 280.0 Episode number: 262
# Epochs per episode: 689 Episode Reward: 370.0 Episode number: 263
# Epochs per episode: 891 Episode Reward: 370.0 Episode number: 264
# Epochs per episode: 1011 Episode Reward: 590.0 Episode number: 265
# Epochs per episode: 489 Episode Reward: 200.0 Episode number: 266
# Epochs per episode: 685 Episode Reward: 410.0 Episode number: 267
# Epochs per episode: 853 Episode Reward: 550.0 Episode number: 268
# Epochs per episode: 971 Episode Reward: 490.0 Episode number: 269
# Epochs per episode: 637 Episode Reward: 300.0 Episode number: 270
# Epochs per episode: 763 Episode Reward: 440.0 Episode number: 271
# Epochs per episode: 920 Episode Reward: 680.0 Episode number: 272
# Epochs per episode: 583 Episode Reward: 230.0 Episode number: 273
# Epochs per episode: 596 Episode Reward: 190.0 Episode number: 274
# Epochs per episode: 484 Episode Reward: 190.0 Episode number: 275
# Epochs per episode: 677 Episode Reward: 230.0 Episode number: 276
# Epochs per episode: 512 Episode Reward: 280.0 Episode number: 277
# Epochs per episode: 439 Episode Reward: 180.0 Episode number: 278
# Epochs per episode: 947 Episode Reward: 700.0 Episode number: 279
# Epochs per episode: 510 Episode Reward: 180.0 Episode number: 280
# Epochs per episode: 694 Episode Reward: 430.0 Episode number: 281
# Epochs per episode: 587 Episode Reward: 340.0 Episode number: 282
# Epochs per episode: 1499 Episode Reward: 1480.0 Episode number: 283
# Epochs per episode: 1111 Episode Reward: 880.0 Episode number: 284
# Epochs per episode: 783 Episode Reward: 540.0 Episode number: 285
# Epochs per episode: 1113 Episode Reward: 540.0 Episode number: 286
# Epochs per episode: 776 Episode Reward: 400.0 Episode number: 287
# Epochs per episode: 759 Episode Reward: 430.0 Episode number: 288
# Epochs per episode: 869 Episode Reward: 460.0 Episode number: 289
# Epochs per episode: 662 Episode Reward: 270.0 Episode number: 290
# Epochs per episode: 648 Episode Reward: 310.0 Episode number: 291
# Epochs per episode: 1003 Episode Reward: 820.0 Episode number: 292
# Epochs per episode: 877 Episode Reward: 420.0 Episode number: 293
# Epochs per episode: 605 Episode Reward: 370.0 Episode number: 294
# Epochs per episode: 509 Episode Reward: 240.0 Episode number: 295
# Epochs per episode: 1122 Episode Reward: 1280.0 Episode number: 296
# Epochs per episode: 679 Episode Reward: 340.0 Episode number: 297
# Epochs per episode: 774 Episode Reward: 390.0 Episode number: 298
# Epochs per episode: 709 Episode Reward: 380.0 Episode number: 299
# Epochs per episode: 837 Episode Reward: 490.0 Episode number: 300
# Epochs per episode: 637 Episode Reward: 330.0 Episode number: 301
# Epochs per episode: 658 Episode Reward: 320.0 Episode number: 302
# Epochs per episode: 804 Episode Reward: 720.0 Episode number: 303
# Epochs per episode: 868 Episode Reward: 900.0 Episode number: 304
# Epochs per episode: 611 Episode Reward: 350.0 Episode number: 305
# Epochs per episode: 781 Episode Reward: 530.0 Episode number: 306
# Epochs per episode: 500 Episode Reward: 190.0 Episode number: 307
# Epochs per episode: 653 Episode Reward: 210.0 Episode number: 308
# Epochs per episode: 909 Episode Reward: 510.0 Episode number: 309
# Epochs per episode: 777 Episode Reward: 330.0 Episode number: 310
# Epochs per episode: 653 Episode Reward: 340.0 Episode number: 311
# Epochs per episode: 856 Episode Reward: 390.0 Episode number: 312
# Epochs per episode: 715 Episode Reward: 240.0 Episode number: 313
# Epochs per episode: 558 Episode Reward: 240.0 Episode number: 314
# Epochs per episode: 804 Episode Reward: 430.0 Episode number: 315
# Epochs per episode: 630 Episode Reward: 190.0 Episode number: 316
# Epochs per episode: 1168 Episode Reward: 730.0 Episode number: 317
# Epochs per episode: 855 Episode Reward: 340.0 Episode number: 318
# Epochs per episode: 418 Episode Reward: 170.0 Episode number: 319
# Epochs per episode: 781 Episode Reward: 430.0 Episode number: 320
# Epochs per episode: 435 Episode Reward: 220.0 Episode number: 321
# Epochs per episode: 651 Episode Reward: 320.0 Episode number: 322
# Epochs per episode: 880 Episode Reward: 650.0 Episode number: 323
# Epochs per episode: 608 Episode Reward: 260.0 Episode number: 324
# Epochs per episode: 656 Episode Reward: 370.0 Episode number: 325
# Epochs per episode: 533 Episode Reward: 250.0 Episode number: 326
# Epochs per episode: 916 Episode Reward: 1080.0 Episode number: 327
# Epochs per episode: 485 Episode Reward: 220.0 Episode number: 328
# Epochs per episode: 701 Episode Reward: 370.0 Episode number: 329
# Epochs per episode: 829 Episode Reward: 620.0 Episode number: 330
# Epochs per episode: 667 Episode Reward: 220.0 Episode number: 331
# Epochs per episode: 692 Episode Reward: 970.0 Episode number: 332
# Epochs per episode: 563 Episode Reward: 250.0 Episode number: 333
# Epochs per episode: 1496 Episode Reward: 1140.0 Episode number: 334
# Epochs per episode: 671 Episode Reward: 390.0 Episode number: 335
# Epochs per episode: 485 Episode Reward: 220.0 Episode number: 336
# Epochs per episode: 1048 Episode Reward: 520.0 Episode number: 337
# Epochs per episode: 631 Episode Reward: 340.0 Episode number: 338
# Epochs per episode: 760 Episode Reward: 460.0 Episode number: 339
# Epochs per episode: 885 Episode Reward: 620.0 Episode number: 340
# Epochs per episode: 827 Episode Reward: 670.0 Episode number: 341
# Epochs per episode: 1001 Episode Reward: 560.0 Episode number: 342
# Epochs per episode: 928 Episode Reward: 720.0 Episode number: 343
# Epochs per episode: 605 Episode Reward: 400.0 Episode number: 344
# Epochs per episode: 763 Episode Reward: 310.0 Episode number: 345
# Epochs per episode: 893 Episode Reward: 610.0 Episode number: 346
# Epochs per episode: 843 Episode Reward: 610.0 Episode number: 347
# Epochs per episode: 757 Episode Reward: 640.0 Episode number: 348
# Epochs per episode: 405 Episode Reward: 140.0 Episode number: 349
# Epochs per episode: 846 Episode Reward: 920.0 Episode number: 350
# Epochs per episode: 616 Episode Reward: 420.0 Episode number: 351
# Epochs per episode: 644 Episode Reward: 440.0 Episode number: 352
# Epochs per episode: 631 Episode Reward: 310.0 Episode number: 353
# Epochs per episode: 1311 Episode Reward: 1630.0 Episode number: 354
# Epochs per episode: 955 Episode Reward: 860.0 Episode number: 355
# Epochs per episode: 571 Episode Reward: 350.0 Episode number: 356
# Epochs per episode: 851 Episode Reward: 580.0 Episode number: 357
# Epochs per episode: 618 Episode Reward: 530.0 Episode number: 358
# Epochs per episode: 650 Episode Reward: 350.0 Episode number: 359
# Epochs per episode: 698 Episode Reward: 220.0 Episode number: 360
# Epochs per episode: 1264 Episode Reward: 750.0 Episode number: 361
# Epochs per episode: 632 Episode Reward: 430.0 Episode number: 362
# Epochs per episode: 971 Episode Reward: 740.0 Episode number: 363
# Epochs per episode: 909 Episode Reward: 510.0 Episode number: 364
# Epochs per episode: 1331 Episode Reward: 1510.0 Episode number: 365
# Epochs per episode: 840 Episode Reward: 880.0 Episode number: 366
# Epochs per episode: 1254 Episode Reward: 1530.0 Episode number: 367
# Epochs per episode: 494 Episode Reward: 200.0 Episode number: 368
# Epochs per episode: 640 Episode Reward: 270.0 Episode number: 369
# Epochs per episode: 741 Episode Reward: 450.0 Episode number: 370
# Epochs per episode: 601 Episode Reward: 310.0 Episode number: 371
# Epochs per episode: 757 Episode Reward: 740.0 Episode number: 372
# Epochs per episode: 863 Episode Reward: 490.0 Episode number: 373
# Epochs per episode: 838 Episode Reward: 560.0 Episode number: 374
# Epochs per episode: 631 Episode Reward: 420.0 Episode number: 375
# Epochs per episode: 857 Episode Reward: 1750.0 Episode number: 376
# Epochs per episode: 675 Episode Reward: 360.0 Episode number: 377
# Epochs per episode: 563 Episode Reward: 190.0 Episode number: 378
# Epochs per episode: 638 Episode Reward: 310.0 Episode number: 379
# Epochs per episode: 793 Episode Reward: 490.0 Episode number: 380
# Epochs per episode: 579 Episode Reward: 230.0 Episode number: 381
# Epochs per episode: 575 Episode Reward: 250.0 Episode number: 382
# Epochs per episode: 637 Episode Reward: 390.0 Episode number: 383
# Epochs per episode: 561 Episode Reward: 350.0 Episode number: 384
# Epochs per episode: 625 Episode Reward: 370.0 Episode number: 385
# Epochs per episode: 645 Episode Reward: 220.0 Episode number: 386
# Epochs per episode: 774 Episode Reward: 400.0 Episode number: 387
# Epochs per episode: 580 Episode Reward: 270.0 Episode number: 388
# Epochs per episode: 549 Episode Reward: 250.0 Episode number: 389
# Epochs per episode: 433 Episode Reward: 170.0 Episode number: 390
# Epochs per episode: 901 Episode Reward: 1910.0 Episode number: 391
# Epochs per episode: 577 Episode Reward: 320.0 Episode number: 392
# Epochs per episode: 1130 Episode Reward: 750.0 Episode number: 393
# Epochs per episode: 722 Episode Reward: 370.0 Episode number: 394
# Epochs per episode: 635 Episode Reward: 320.0 Episode number: 395
# Epochs per episode: 893 Episode Reward: 370.0 Episode number: 396
# Epochs per episode: 761 Episode Reward: 670.0 Episode number: 397
# Epochs per episode: 640 Episode Reward: 390.0 Episode number: 398
# Epochs per episode: 555 Episode Reward: 270.0 Episode number: 399
# Epochs per episode: 754 Episode Reward: 450.0 Episode number: 400

# %% [markdown]
# Let's plot our reward distribution across the incremental episodes. Remember to interrupt the training process first.

# %%
plt.plot(history,'xk',label="400 epoche lr=0.01 epsilon=1")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluation
#
# Finally, let's visualize our agent's performance, and play a game within the gym environment itself.

# %%
#Visualization cobe for running within Colab

# Install dependencies first for graphics visualization within Colaboratory

#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# Out:
# Collecting setuptools
#   Downloading https://files.pythonhosted.org/packages/d0/15/5041473f5d142ee93bf1593deb8f932e27a078f6f04e2020cf44044f72c5/setuptools-56.2.0-py3-none-any.whl (785kB)
#      |████████████████████████████████| 788kB 9.1MB/s
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: setuptools
#   Found existing installation: setuptools 56.1.0
#     Uninstalling setuptools-56.1.0:
#       Successfully uninstalled setuptools-56.1.0
# Successfully installed setuptools-56.2.0

# %%
#To Evaluate model on OpenAI gym, we will record a video via Ipython display



from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay


from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
#Evaluate model on openAi GYM
env = wrap_env(gym.make('MsPacman-v0'))
observation = env.reset()
new_observation = observation

prev_input = None
done = False

with tf.compat.v1.Session() as sess:
    init.run()
    while True:
      if True: 
    
        #set input to network to be difference image
    

        obs = preprocess_observation(observation)

        # feed the game screen and get the Q values for each action
        actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})

        # get the action
        action = np.argmax(actions, axis=-1)
        actions_counter[str(action)] += 1 

        # select the action using epsilon greedy policy
        action = epsilon_greedy(action, global_step)
        env.render()
        observation = new_observation        
        # now perform the action and move to the next state, next_obs, receive reward
        new_observation, reward, done, _ = env.step(action)

        if done: 
          #observation = env.reset()
          break
      
    env.close()
    show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
